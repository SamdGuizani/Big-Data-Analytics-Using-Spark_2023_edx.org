# %% [markdown]
# # Twitter Analysis
#
# ## Introduction
#
# In this homework, we are going to play with Twitter data.
#
# The data is represented as rows of of [JSON](https://en.wikipedia.org/wiki/JSON#Example) strings.
# It consists of tweets, messages, and a small amount of broken data (cannot be parsed as JSON).
#
# For this homework, we will only focus on tweets and ignore all other messages.
#
# **Search for `Tasks` to find out what you need to implement. You should only replace**
#
# ```
# ###
# ### YOUR CODE HERE
# ###
# ```
#
# **with your code.**

# %% [markdown]
# ## Data overview
#
# ### Tweets
#
# A tweet consists of many data fields. You can learn all about them in the Twitter API doc. We are going to briefly introduce only the data fields that will be used in this homework.
#
# * `created_at`: Posted time of this tweet (time zone is included)
# * `id_str`: Tweet ID - we recommend using `id_str` over using `id` as Tweet IDs, becauase `id` is an integer and may bring some overflow problems.
# * `text`: Tweet content
# * `user`: A JSON object for information about the author of the tweet
#     * `id_str`: User ID
#     * `name`: User name (may contain spaces)
#     * `screen_name`: User screen name (no spaces)
# * `retweeted_status`: A JSON object for information about the retweeted tweet (i.e. this tweet is not original but retweeteed some other tweet)
#     * All data fields of a tweet except `retweeted_status`
# * `entities`: A JSON object for all entities in this tweet
#     * `hashtags`: An array for all the hashtags that are mentioned in this tweet
#     * `urls`: An array for all the URLs that are mentioned in this tweet
#
#
# ### Users partition
#
# Besides the original tweets, we will provide you with a Pickle file, which contains a partition over 452,743 Twitter users. It contains a Python dictionary `{user_id: partition_id}`. The users are partitioned into 7 groups.

# %% [markdown]
# ## Grading
#
# ### Scale on datasets with different sizes
#
# Your implementation for this assignment will be graded on both correctness and runtimes. You will have a 0 score if your results do not match the expected values for each data set. If your results are correct, your score is dependent on the runtime.
#
# On Vocareum, we provide three different input sizes to test your program: 10 MB, 1 GB, and 10 GB. For any run, we will only be using one of these 3 datasets. **You can switch between different parts on Vocareum to test on different data files.** When you submit, you will be graded only for the part you have selected.
#
# Although there are 3 different parts, **we will only provide the standard answers for the 10 MB part**, which are given as
#
# > ---
# > **It should print**
#
# in the write-ups below. If you follow the instructions below to develop your solution for the 10 MB part, it should also produce the correct results for other parts.
#
# **Don't change any print funcitons that we provided in the starter code.** In the grading process, the correctness of your solution is checked by comparing the content of the variables, NOT the printed outputs.

# %% [markdown]
# ### Running locally and on clusters
#
# The Spark application will run locally with limited resources when you develop your program in the Jupyter notebook. However, when you submit your solution for grading, your implementation will be first converted to a python script and then submitted to a Spark cluster with much more resources for correctness and runtime evaluations.
#
# Due to resource constraints, you cannot use the Spark cluster while developing your solution.

# %%
# `ON_EMR` indicates whether your program is running locally or on the clusters.
# We assume it will run locally if this script is in the interactive mode (jupyter notebook) 
# and run on clusters if it is invoked by a shell command.
# DO NOT CHANGE THE VALUE OF `ON_EMR` in your program.

import sys

ON_EMR = not hasattr(sys, 'ps1')
print('Your program will run {}'.format(['locally', 'on clusters'][ON_EMR]))
# Out:
# Your program will run locally

# %% [markdown]
# ### OutputLogger
#
# `OutputLogger` object `my_output` is defined to store the results of your program. We have provided function calls to `my_output.append()` method for storing the results in all necessary places. In the last cell of this file, we write the content of `my_output` to a pickle file which the grader will read in and use for grading.
#
# **We have already appended all necessary variables to `my_output` in the starter code. Thus, don't change anything related to `my_output` or add more results to `my_output`. **

# %%
import os
import sys
os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

import pickle

class OutputLogger:
    def __init__(self):
        self.ans = {}

    def append(self, key, value):
        self.ans[key] = value

    def write_to_disk(self):
        filepath = os.path.expanduser("answer.pickle")
        with open(filepath, 'wb') as f:
            pickle.dump(self.ans, f)
        
        # If ON_EMR, copy answer.pickle from the driver to HDFS
        if ON_EMR:
            proc = subprocess.Popen(["/usr/local/hadoop/hadoop-2.7.4/bin/hadoop", "fs", "-copyFromLocal", filepath, "/user/spark/answer.pickle"])
            proc.wait()
            os.remove(filepath)

my_output = OutputLogger()

# %% [markdown]
# ### Measuring runtime
#
# This is a useful cell for debugging. You can use `save_time(key)` at different parts of your code for checking the amount of time a segment takes. We have added it to the different parts of the starter code. You are free to use it where appropriate.

# %%
from time import time
import datetime

timer = {}
def save_time(key):
    '''
    Calling save_time with 'key' the first time will record the current time for 'key'.
    Calling save_time with 'key' the second time will record the time (hours:minutes:seconds) 
    it takes from the first calling to the second calling. All results will be saved
    in timer dict.
    Calling save_time with 'key' the third time will overwrite existing data.
    
    Args:
        key: an identifier for this time.
    '''
    
    if key in timer: 
        if type(timer[key]) == str:
            timer[key] = time()
        else:
            timer[key] = str(datetime.timedelta(seconds=round(time() - timer[key])))
    else:
        timer[key] = time()
                
save_time('total time')

# %% [markdown]
# ## Part 0: Load data to an RDD

# %%
save_time("set up sc")

from pyspark import SparkContext

sc = SparkContext()

save_time("set up sc")

# %% [markdown]
# ### Read text file
#
# For local testing, the data files are in a public directory where you can read the file directly. The path to the data file is hard-coded in the `file_path` variable as part of the starter code.
#
# For submission, we will create this file on our server for testing with the appropriate file path. You should not worry about which file system (i.e. local file system or HDFS) Spark will read data from since the `file_path` variable we provide below will always contain the correct path to the data file.
#
# **Tasks:**
#
# 1. Make RDD from the data in the file given by `file_path`.
# 2. Mark the RDD to be cached (so in the next operation data will be loaded in memory)
# 3. Count the number of elements in the RDD and store the result in `num_tweets`.
#
# **Hint:** use [`sc.textFile()`](https://spark.apache.org/docs/2.3.0/api/python/pyspark.html#pyspark.SparkContext.textFile) to read the text file into an RDD.
#
# ***
#
# **It should print**
# ```
# Number of elements: 2150
# ```

# %%
save_time("read data")

if ON_EMR:
    file_path = '/user/spark/twitter/twitter.txt'
else:
    file_path = './resource/asnlib/publicdata/twitter.txt'

###
### YOUR CODE HERE
###
rdd = sc.textFile(file_path)
rdd = rdd.cache()
num_tweets = rdd.count()

my_output.append("num-tweets", num_tweets)
print('Number of elements:', num_tweets)
save_time("read data")
# Out:
# Number of elements: 225000

# %%
# Test: visualize an element:
rdd.sample(False, 1/1250).collect()
# Out:
# ['{"created_at":"Wed Feb 10 20:54:51 +0000 2016","id":697524148860383232,"id_str":"697524148860383232","text":"RT @SassyTassie102P: Bernie Sanders is a HAS BEEN JEW THOUGHT. Today\'s Jew does not hold to COMMUNISTIC IDEALS. The US Jewish population to\\u2026","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":783841712,"id_str":"783841712","name":"marilee reddin","screen_name":"marileereddin","location":null,"url":null,"description":null,"protected":false,"verified":false,"followers_count":16,"friends_count":249,"listed_count":0,"favourites_count":280,"statuses_count":333,"created_at":"Mon Aug 27 04:55:27 +0000 2012","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/abs.twimg.com\\/sticky\\/default_profile_images\\/default_profile_3_normal.png","profile_image_url_https":"https:\\/\\/abs.twimg.com\\/sticky\\/default_profile_images\\/default_profile_3_normal.png","default_profile":true,"default_profile_image":true,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 20:41:34 +0000 2016","id":697520806121730049,"id_str":"697520806121730049","text":"Bernie Sanders is a HAS BEEN JEW THOUGHT. Today\'s Jew does not hold to COMMUNISTIC IDEALS. The US Jewish population today support REPUBLIC.","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":107507375,"id_str":"107507375","name":"Karil McL","screen_name":"SassyTassie102P","location":"La Porte, TX","url":"http:\\/\\/twitter.com\\/sassytassie102p","description":"TOTALLY NOT politically correct. Do not try to shut me up. WON\'T WORK. Will always say what is on my mind.","protected":false,"verified":false,"followers_count":2113,"friends_count":1853,"listed_count":41,"favourites_count":608,"statuses_count":19495,"created_at":"Fri Jan 22 20:06:48 +0000 2010","utc_offset":-21600,"time_zone":"Central Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"8B542B","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme8\\/bg.gif","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme8\\/bg.gif","profile_background_tile":false,"profile_link_color":"9D582E","profile_sidebar_border_color":"D9B17E","profile_sidebar_fill_color":"EADEAA","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/654992958769332226\\/EYu1Vw9g_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/654992958769332226\\/EYu1Vw9g_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/107507375\\/1444997374","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false, ...
#  '{"created_at":"Wed Feb 10 20:55:00 +0000 2016","id":697524188404256768,"id_str":"697524188404256768","text":"I truly believe trump is the antichrist","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2931504998,"id_str":"2931504998","name":"yairA","screen_name":"princessyairaa","location":"down yonder","url":null,"description":"if God brings you to it, he\'ll bring you through it","protected":false,"verified":false,"followers_count":323,"friends_count":307,"listed_count":0,"favourites_count":8772,"statuses_count":13222,"created_at":"Mon Dec 15 18:45:40 +0000 2014","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/696702707625689088\\/JQiqdW_P_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/696702707625689088\\/JQiqdW_P_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/2931504998\\/1454825159","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[],"user_mentions":[],"symbols":[]},"favorited":false,"retweeted":false,"filter_level":"low","lang":"en","timestamp_ms":"1455137700545"}',
#  '{"created_at":"Wed Feb 10 20:55:01 +0000 2016","id":697524190853791744,"id_str":"697524190853791744","text":"RT @TheDailyShow: 2\\/ FREE TUITION! FREE HEALTHCARE! FREE THROWS! https:\\/\\/t.co\\/9lTKrk817B","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":981714924,"id_str":"981714924","name":"\\u00af\\\\_(\\u30c4)_\\/\\u00af REEN","screen_name":"renevilla__","location":"Barcelona, Catalonia","url":null,"description":"\\u26bd\\ufe0f and V.M","protected":false,"verified":false,"followers_count":389,"friends_count":540,"listed_count":2,"favourites_count":3654,"statuses_count":15893,"created_at":"Sat Dec 01 03:15:30 +0000 2012","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"022330","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme15\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme15\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"A8C7F7","profile_sidebar_fill_color":"C0DFEC","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/691430492063662082\\/9ao2I4ys_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/691430492063662082\\/9ao2I4ys_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/981714924\\/1446770865","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 20:42:08 +0000 2016","id":697520950720462849,"id_str":"697520950720462849","text":"2\\/ FREE TUITION! FREE HEALTHCARE! FREE THROWS! https:\\/\\/t.co\\/9lTKrk817B","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":697520860337405952,"in_reply_to_status_id_str":"697520860337405952","in_reply_to_user_id":158414847,"in_reply_to_user_id_str":"158414847","in_reply_to_screen_name":"TheDailyShow","user":{"id":158414847,"id_str":"158414847","name":"The Daily Show","screen_name":"TheDailyShow","location":null,"url":"http:\\/\\/thedailyshow.com","description":"Trevor Noah and The Best F#@king News Team. Weeknights 11\\/10c on @ComedyCentral. Full episodes, videos, guest information. #DailyShow","protected":false,"verified":true,"followers_count":4065758,"friends_count":280,"listed_count":36184,"favourites_count":20,"statuses_count":9199,"created_at":"Tue Jun 22 16:41:05 +0000 2010","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/661306435620376576\\/S7ZtR4fI.jpg","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/661306435620376576\\/S7ZtR4fI.jpg","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/633669033708142592\\/jtJpbgKj_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/633669033708142592\\/jtJpbgKj_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/158414847\\/1446498480","default_profile":false,"default_profile_image":false,"fol ...
#  '{"created_at":"Wed Feb 10 20:55:20 +0000 2016","id":697524272164683776,"id_str":"697524272164683776","text":"#Entertainment #Google\\u2019s Next \\u2018Moonshot\\u2019? Making Bernie Sanders President https:\\/\\/t.co\\/E4hhKns14v","source":"\\u003ca href=\\"http:\\/\\/ifttt.com\\" rel=\\"nofollow\\"\\u003eIFTTT\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2884902505,"id_str":"2884902505","name":"Ervin Flora","screen_name":"iErvinFlora","location":null,"url":null,"description":null,"protected":false,"verified":false,"followers_count":1864,"friends_count":1948,"listed_count":14,"favourites_count":0,"statuses_count":37824,"created_at":"Fri Oct 31 11:23:34 +0000 2014","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/568106336676630528\\/kYSFrqxw_normal.jpeg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/568106336676630528\\/kYSFrqxw_normal.jpeg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[{"text":"Entertainment","indices":[0,14]},{"text":"Google","indices":[15,22]}],"urls":[{"url":"https:\\/\\/t.co\\/E4hhKns14v","expanded_url":"http:\\/\\/bit.ly\\/1SITUBB","display_url":"bit.ly\\/1SITUBB","indices":[74,97]}],"user_mentions":[],"symbols":[]},"favorited":false,"retweeted":false,"possibly_sensitive":false,"filter_level":"low","lang":"en","timestamp_ms":"1455137720515"}',
#  '{"created_at":"Wed Feb 10 20:55:26 +0000 2016","id":697524299112927232,"id_str":"697524299112927232","text":"@CarlyFiorina Please endorse @tedcruz","source":"\\u003ca href=\\"https:\\/\\/mobile.twitter.com\\" rel=\\"nofollow\\"\\u003eMobile Web (M5)\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":697512258595782656,"in_reply_to_status_id_str":"697512258595782656","in_reply_to_user_id":65691824,"in_reply_to_user_id_str":"65691824","in_reply_to_screen_name":"CarlyFiorina","user":{"id":44804947,"id_str":"44804947","name":"eileen graves","screen_name":"how66","location":null,"url":null,"description":null,"protected":false,"verified":false,"followers_count":14,"friends_count":57,"listed_count":1,"favourites_count":5,"statuses_count":185,"created_at":"Fri Jun 05 02:59:39 +0000 2009","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/2807729647\\/5d7d938915249507ffde98cae8293bd4_normal.jpeg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/2807729647\\/5d7d938915249507ffde98cae8293bd4_normal.jpeg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[],"user_mentions":[{"screen_name":"CarlyFiorina","name":"Carly Fiorina","id":65691824,"id_str":"65691824","indices":[0,13]},{"screen_name":"tedcruz","name":"Ted Cruz","id":23022687,"id_str":"23022687","indices":[29,37]}],"symbols":[]},"favorited":false,"retweeted":false,"filter_level":"low","lang":"en","timestamp_ms":"1455137726940"}',
#  '{"created_at":"Wed Feb 10 20:55:54 +0000 2016","id":697524415731539968,"id_str":"697524415731539968","text":"RT @kirkz2006: @mistyfoggyriver @MaywoodCB @JackieJackielg He has the most votes for any Republican ever in Iowa and NH combined.","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":27587178,"id_str":"27587178","name":"Angel777TN","screen_name":"AngelaTN777","location":"Nashville, TN","url":null,"description":"Just a Country Girl at He\\u2661rt.  One who loves #God #Family #Country #Music. #USA\\n  Life is an occasion , rise to it!\\n\\n\\u2661\\u2661Life is Precious -Always be Grateful \\u2661\\u2661","protected":false,"verified":false,"followers_count":1227,"friends_count":2202,"listed_count":41,"favourites_count":5684,"statuses_count":20148,"created_at":"Mon Mar 30 04:52:59 +0000 2009","utc_offset":-21600,"time_zone":"Central Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"8B542B","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme8\\/bg.gif","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme8\\/bg.gif","profile_background_tile":false,"profile_link_color":"9D582E","profile_sidebar_border_color":"D9B17E","profile_sidebar_fill_color":"EADEAA","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/625393027943690241\\/zn648B8-_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/625393027943690241\\/zn648B8-_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/27587178\\/1454794785","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 20:51:36 +0000 2016","id":697523331122200576,"id_str":"697523331122200576","text":"@mistyfoggyriver @MaywoodCB @JackieJackielg He has the most votes for any Republican ever in Iowa and NH combined.","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":697522904255307776,"in_reply_to_status_id_str":"697522904255307776","in_reply_to_user_id":3729906627,"in_reply_to_user_id_str":"3729906627","in_reply_to_screen_name":"mistyfoggyriver","user":{"id":2823033810,"id_str":"2823033810","name":"Kirk Z","screen_name":"kirkz2006","location":null,"url":null,"description":"Christian, conservative, sports fan.","protected":false,"verified":false,"followers_count":358,"friends_count":357,"listed_count":23,"favourites_count":2705,"statuses_count":11953,"created_at":"Sun Sep 21 00:40:38 +0000 2014","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/624602345830125568\\/ln6vYY_a_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/624602345830125568\\/ln6vYY_a_normal.jpg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":nul ...
#  '{"created_at":"Wed Feb 10 20:56:39 +0000 2016","id":697524604168830976,"id_str":"697524604168830976","text":"RT @TheDailyShow: .@BernieSanders\\u2019 popularity among women could earn him something bigger than the presidency. https:\\/\\/t.co\\/tBwSHCdKKk http\\u2026","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":329792329,"id_str":"329792329","name":"somekindofstripper","screen_name":"mirandaxconley","location":"wichita, ks","url":null,"description":"23. noelle. queer. intersectional feminist. straight edge. atheist. stripper. cat lady.","protected":false,"verified":false,"followers_count":592,"friends_count":286,"listed_count":15,"favourites_count":22225,"statuses_count":31213,"created_at":"Tue Jul 05 16:41:37 +0000 2011","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"ACDED6","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme18\\/bg.gif","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme18\\/bg.gif","profile_background_tile":false,"profile_link_color":"038543","profile_sidebar_border_color":"EEEEEE","profile_sidebar_fill_color":"F6F6F6","profile_text_color":"333333","profile_use_background_image":false,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/691383895623794688\\/_wPsZjR7_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/691383895623794688\\/_wPsZjR7_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/329792329\\/1453674149","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 19:30:01 +0000 2016","id":697502800293556224,"id_str":"697502800293556224","text":".@BernieSanders\\u2019 popularity among women could earn him something bigger than the presidency. https:\\/\\/t.co\\/tBwSHCdKKk https:\\/\\/t.co\\/mOcAFXeBL1","source":"\\u003ca href=\\"http:\\/\\/www.sprinklr.com\\" rel=\\"nofollow\\"\\u003eSprinklr\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":158414847,"id_str":"158414847","name":"The Daily Show","screen_name":"TheDailyShow","location":null,"url":"http:\\/\\/thedailyshow.com","description":"Trevor Noah and The Best F#@king News Team. Weeknights 11\\/10c on @ComedyCentral. Full episodes, videos, guest information. #DailyShow","protected":false,"verified":true,"followers_count":4065763,"friends_count":280,"listed_count":36184,"favourites_count":20,"statuses_count":9199,"created_at":"Tue Jun 22 16:41:05 +0000 2010","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/661306435620376576\\/S7ZtR4fI.jpg","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/661306435620376576\\/S7ZtR4fI.jpg","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/633669033708142592\\/jtJpbgKj_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/633669033708142592\\/jtJpbgKj_normal.j ...
#  '{"created_at":"Wed Feb 10 20:57:07 +0000 2016","id":697524722356002816,"id_str":"697524722356002816","text":"RT @EricBoehlert: Sanders HQ had to turn off live feed of Clinton speech last night; supporters were hurling so many insults at her. https:\\u2026","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2839231382,"id_str":"2839231382","name":"Tina Rufo","screen_name":"RufoTina","location":null,"url":null,"description":"Below the radar","protected":false,"verified":false,"followers_count":58,"friends_count":69,"listed_count":9,"favourites_count":1763,"statuses_count":1159,"created_at":"Fri Oct 03 16:51:56 +0000 2014","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/695659745059844096\\/io1TBZfR_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/695659745059844096\\/io1TBZfR_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/2839231382\\/1453581420","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Tue Feb 02 12:34:20 +0000 2016","id":694499087895379968,"id_str":"694499087895379968","text":"Sanders HQ had to turn off live feed of Clinton speech last night; supporters were hurling so many insults at her. https:\\/\\/t.co\\/xOn6CaCnzD","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":34643610,"id_str":"34643610","name":"Eric Boehlert","screen_name":"EricBoehlert","location":null,"url":"http:\\/\\/www.MediaMatters.org\\/","description":"Media Matters guy. Author. former staffer at Salon, Rolling Stone and Billboard. Bowler. Utica Club aficionado. Opinions  my own. Especially ones that offend","protected":false,"verified":false,"followers_count":47935,"friends_count":747,"listed_count":2386,"favourites_count":14,"statuses_count":57621,"created_at":"Thu Apr 23 15:39:39 +0000 2009","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"174A82","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/9860779\\/book.jpg","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/9860779\\/book.jpg","profile_background_tile":false,"profile_link_color":"336699","profile_sidebar_border_color":"336699","profile_sidebar_fill_color":"DBE1F2","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/606924518192324608\\/cTfPF0o9_normal.png","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/606924518192324608\\/cTfPF0o9_normal.png","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":nu ...
#  '{"created_at":"Wed Feb 10 20:57:27 +0000 2016","id":697524803000004611,"id_str":"697524803000004611","text":"He is a candidate cuz he has inside backing...And his backing is not the Republican Party... He\'s a traitor #HaLfWiG https:\\/\\/t.co\\/0MQsXhDO0r","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":117200890,"id_str":"117200890","name":"(\\u039c\\u03bf\\u03bb\\u03ce\\u03bd \\u039ba\\u03b2\\u03ad)","screen_name":"theseedsowerz","location":"The Bronx","url":"http:\\/\\/theseedsowerz.com","description":"Super Muse Extraordinaire seeking to boggle your minds with wisdom & poetic justice... #Journalist #Anarchist #Poet #Lyricist #Revolutionary #BADASS","protected":false,"verified":false,"followers_count":38560,"friends_count":36250,"listed_count":184,"favourites_count":4801,"statuses_count":38687,"created_at":"Wed Feb 24 21:32:03 +0000 2010","utc_offset":-14400,"time_zone":"Atlantic Time (Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"352726","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme5\\/bg.gif","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme5\\/bg.gif","profile_background_tile":false,"profile_link_color":"000000","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"99CC33","profile_text_color":"3E4415","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/716303564\\/me_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/716303564\\/me_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/117200890\\/1398253101","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"quoted_status_id":697524269484355584,"quoted_status_id_str":"697524269484355584","quoted_status":{"created_at":"Wed Feb 10 20:55:19 +0000 2016","id":697524269484355584,"id_str":"697524269484355584","text":"@theseedsowerz What if he really is the jerk he pretends to be and does want to win?","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":697523923282485248,"in_reply_to_status_id_str":"697523923282485248","in_reply_to_user_id":117200890,"in_reply_to_user_id_str":"117200890","in_reply_to_screen_name":"theseedsowerz","user":{"id":470837311,"id_str":"470837311","name":"The Kenny Kenneth","screen_name":"KennyAllon","location":"USA","url":"http:\\/\\/www.youtube.com\\/user\\/HRHkentable?feature=mhee","description":"SONGWRITER. Seeker of freedom. Avid Peanut Butterist. I hardly have any FACEBOOK friends.*Sniff sniff*","protected":false,"verified":false,"followers_count":926,"friends_count":1051,"listed_count":2,"favourites_count":454,"statuses_count":6100,"created_at":"Sun Jan 22 06:18:05 +0000 2012","utc_offset":-21600,"time_zone":"Central Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"0099B9","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme4\\/bg.gif","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme4\\/bg.gif","profile_background_tile":false,"profile_link_color":"0099B9","profile_sidebar_border_color":"5ED4DC","profile_sidebar_fill_color":"95E8EC","profile_text_color":"3C3940","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/697505069994868736\\/maU50i7E_normal.jpg","profile_image_url_https":"https:\\/\\/pbs ...
#  '{"created_at":"Wed Feb 10 20:58:35 +0000 2016","id":697525090704035840,"id_str":"697525090704035840","text":"RT @jackhunter74: And it was @RandPaul who called our national debt the greatest threat to security.  https:\\/\\/t.co\\/I63uiLc7az","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2758998417,"id_str":"2758998417","name":"Tina Cain","screen_name":"eightball6908","location":null,"url":null,"description":null,"protected":false,"verified":false,"followers_count":149,"friends_count":398,"listed_count":5,"favourites_count":1916,"statuses_count":528,"created_at":"Tue Sep 02 05:21:37 +0000 2014","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/669698619189141504\\/W9lUSJMd_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/669698619189141504\\/W9lUSJMd_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/2758998417\\/1448503566","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 00:06:45 +0000 2016","id":697210055645499392,"id_str":"697210055645499392","text":"And it was @RandPaul who called our national debt the greatest threat to security.  https:\\/\\/t.co\\/I63uiLc7az","source":"\\u003ca href=\\"https:\\/\\/about.twitter.com\\/products\\/tweetdeck\\" rel=\\"nofollow\\"\\u003eTweetDeck\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":17823790,"id_str":"17823790","name":"Jack Hunter","screen_name":"jackhunter74","location":"Washington, DC","url":"http:\\/\\/rare.us\\/voices\\/jack-hunter\\/","description":"Editor @Rare","protected":false,"verified":true,"followers_count":11332,"friends_count":3042,"listed_count":451,"favourites_count":452,"statuses_count":7845,"created_at":"Wed Dec 03 00:42:41 +0000 2008","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":false,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/2167788904\\/jack_new_headshot_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/2167788904\\/jack_new_headshot_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/17823790\\/1443540471","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"quoted_status_id":697203801770586112,"quoted_status_i ...
#  '{"created_at":"Wed Feb 10 20:58:55 +0000 2016","id":697525174984290305,"id_str":"697525174984290305","text":"@Tanner_Botts Tiger and Bill Clinton are friends and if that ain\'t a sign he\'s the coolest dude ever idk what is. https:\\/\\/t.co\\/68HHAdbYmD","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":401720974,"in_reply_to_user_id_str":"401720974","in_reply_to_screen_name":"Tanner_Botts","user":{"id":456145765,"id_str":"456145765","name":"Shafe","screen_name":"_Shafe_","location":null,"url":null,"description":"Stay tuned.","protected":false,"verified":false,"followers_count":176,"friends_count":263,"listed_count":11,"favourites_count":46445,"statuses_count":73817,"created_at":"Thu Jan 05 22:47:27 +0000 2012","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/693980042154635264\\/1umq338k_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/693980042154635264\\/1umq338k_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/456145765\\/1451802687","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[],"user_mentions":[{"screen_name":"Tanner_Botts","name":"Tanner","id":401720974,"id_str":"401720974","indices":[0,13]}],"symbols":[],"media":[{"id":697525150800080900,"id_str":"697525150800080900","indices":[114,137],"media_url":"http:\\/\\/pbs.twimg.com\\/media\\/Ca4bbdNW8AQpg80.jpg","media_url_https":"https:\\/\\/pbs.twimg.com\\/media\\/Ca4bbdNW8AQpg80.jpg","url":"https:\\/\\/t.co\\/68HHAdbYmD","display_url":"pic.twitter.com\\/68HHAdbYmD","expanded_url":"http:\\/\\/twitter.com\\/_Shafe_\\/status\\/697525174984290305\\/photo\\/1","type":"photo","sizes":{"small":{"w":340,"h":604,"resize":"fit"},"thumb":{"w":150,"h":150,"resize":"crop"},"medium":{"w":600,"h":1067,"resize":"fit"},"large":{"w":1024,"h":1820,"resize":"fit"}}}]},"extended_entities":{"media":[{"id":697525150800080900,"id_str":"697525150800080900","indices":[114,137],"media_url":"http:\\/\\/pbs.twimg.com\\/media\\/Ca4bbdNW8AQpg80.jpg","media_url_https":"https:\\/\\/pbs.twimg.com\\/media\\/Ca4bbdNW8AQpg80.jpg","url":"https:\\/\\/t.co\\/68HHAdbYmD","display_url":"pic.twitter.com\\/68HHAdbYmD","expanded_url":"http:\\/\\/twitter.com\\/_Shafe_\\/status\\/697525174984290305\\/photo\\/1","type":"photo","sizes":{"small":{"w":340,"h":604,"resize":"fit"},"thumb":{"w":150,"h":150,"resize":"crop"},"medium":{"w":600,"h":1067,"resize":"fit"},"large":{"w":1024,"h":1820,"resize":"fit"}}}]},"favorited":false,"retweeted":false,"possibly_sensitive":false,"filter_level":"low","lang":"en","timestamp_ms":"1455137935764"}',
#  '{"created_at":"Wed Feb 10 20:59:23 +0000 2016","id":697525291695128581,"id_str":"697525291695128581","text":"RT @FrankConniff: Chris Christie is suspending his campaign to spend more time with his family style meals.","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":334732770,"id_str":"334732770","name":"Bill Scheft","screen_name":"billscheft","location":"New York","url":"http:\\/\\/billscheft.com","description":"Letterman writer since 1991, on the street since 12:54 am May 21. My fourth novel, SHRINK THYSELF, is my best.","protected":false,"verified":false,"followers_count":60102,"friends_count":650,"listed_count":202,"favourites_count":4,"statuses_count":4793,"created_at":"Wed Jul 13 15:47:20 +0000 2011","utc_offset":-18000,"time_zone":"Quito","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"DBE9ED","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/456971791022313472\\/NTIsT7_5.png","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/456971791022313472\\/NTIsT7_5.png","profile_background_tile":true,"profile_link_color":"CC3366","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"E6F6F9","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/470237131571335168\\/-S1AgAu0_normal.jpeg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/470237131571335168\\/-S1AgAu0_normal.jpeg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/334732770\\/1397785642","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 20:30:22 +0000 2016","id":697517990552580096,"id_str":"697517990552580096","text":"Chris Christie is suspending his campaign to spend more time with his family style meals.","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":34556109,"id_str":"34556109","name":"Frank Conniff","screen_name":"FrankConniff","location":"New York","url":"http:\\/\\/frankconniff.com\\/","description":"Writer, Comedian, TV\'s Frank","protected":false,"verified":false,"followers_count":50179,"friends_count":4416,"listed_count":2079,"favourites_count":5439,"statuses_count":12101,"created_at":"Thu Apr 23 06:50:54 +0000 2009","utc_offset":-28800,"time_zone":"Pacific Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/661920537459990528\\/qoOh7YAz_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/661920537459990528\\/qoOh7YAz_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/34556109\\/1446650131","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null ...
#  '{"created_at":"Wed Feb 10 20:59:44 +0000 2016","id":697525379049857024,"id_str":"697525379049857024","text":"RT @xeni: The one big thing @BernieSanders\' campaign was missing? An anthem. @MakanaMusic: #FireIsOurs https:\\/\\/t.co\\/Q0nkrtKFMZ https:\\/\\/t.co\\u2026","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":377656370,"id_str":"377656370","name":"Laura Woods","screen_name":"__lew___","location":"planet earth ","url":null,"description":"\\u2728 OC\\u26a1\\ufe0fDC\\u2122 \\u2728 namaste \\u2728","protected":false,"verified":false,"followers_count":74,"friends_count":641,"listed_count":1,"favourites_count":673,"statuses_count":369,"created_at":"Wed Sep 21 22:32:04 +0000 2011","utc_offset":-28800,"time_zone":"Pacific Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"DBE9ED","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/880971679\\/955abedb927ce6a871f669375e407479.jpeg","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/880971679\\/955abedb927ce6a871f669375e407479.jpeg","profile_background_tile":true,"profile_link_color":"CC3366","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/3728517967\\/36e87f6614954cf57079444040870a37_normal.jpeg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/3728517967\\/36e87f6614954cf57079444040870a37_normal.jpeg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/377656370\\/1369855485","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 20:53:08 +0000 2016","id":697523716482203648,"id_str":"697523716482203648","text":"The one big thing @BernieSanders\' campaign was missing? An anthem. @MakanaMusic: #FireIsOurs https:\\/\\/t.co\\/Q0nkrtKFMZ https:\\/\\/t.co\\/syKe3Rlc1k","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":767,"id_str":"767","name":"Xeni","screen_name":"xeni","location":"where data flows","url":"http:\\/\\/xeni.net","description":"@boingboing, @freedomofpress, OG internet journalist. google or subpoena the rest. survivor of breast cancer & other crap. HH @DalaiLama blessed my dog Chappie.","protected":false,"verified":true,"followers_count":94984,"friends_count":3802,"listed_count":5153,"favourites_count":56398,"statuses_count":82928,"created_at":"Fri Jul 14 05:49:14 +0000 2006","utc_offset":-28800,"time_zone":"Pacific Time (US & Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/462391105808388097\\/MMAmbCWF.jpeg","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/462391105808388097\\/MMAmbCWF.jpeg","profile_background_tile":true,"profile_link_color":"FA743E","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDE3F5","profile_text_color":"000000","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/686936532326809600\\/r99SBEWT_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/ ...
# ...
#  '{"created_at":"Wed Feb 10 22:37:10 +0000 2016","id":697549899416514561,"id_str":"697549899416514561","text":"Republican Chris Christie ends bid for the White House https:\\/\\/t.co\\/fGrGLVQMPp https:\\/\\/t.co\\/erE4PGH69s","source":"\\u003ca href=\\"http:\\/\\/dlvr.it\\" rel=\\"nofollow\\"\\u003edlvr.it\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":153207772,"id_str":"153207772","name":"Kogcord","screen_name":"kogcord","location":"Wellington NZ","url":"http:\\/\\/kogcord.blogspot.com\\/","description":null,"protected":false,"verified":false,"followers_count":205,"friends_count":861,"listed_count":10,"favourites_count":0,"statuses_count":3699,"created_at":"Mon Jun 07 23:44:32 +0000 2010","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"EBEBEB","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/119934758\\/Logo.kogcd.png","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/119934758\\/Logo.kogcd.png","profile_background_tile":true,"profile_link_color":"990000","profile_sidebar_border_color":"DFDFDF","profile_sidebar_fill_color":"F3F3F3","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/638510827117539328\\/ulY81TuY_normal.png","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/638510827117539328\\/ulY81TuY_normal.png","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/153207772\\/1441067878","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[{"url":"https:\\/\\/t.co\\/fGrGLVQMPp","expanded_url":"http:\\/\\/dlvr.it\\/KT7rBb","display_url":"dlvr.it\\/KT7rBb","indices":[55,78]}],"user_mentions":[],"symbols":[],"media":[{"id":697549899282264065,"id_str":"697549899282264065","indices":[79,102],"media_url":"http:\\/\\/pbs.twimg.com\\/media\\/Ca4x8AfUMAE7nin.jpg","media_url_https":"https:\\/\\/pbs.twimg.com\\/media\\/Ca4x8AfUMAE7nin.jpg","url":"https:\\/\\/t.co\\/erE4PGH69s","display_url":"pic.twitter.com\\/erE4PGH69s","expanded_url":"http:\\/\\/twitter.com\\/kogcord\\/status\\/697549899416514561\\/photo\\/1","type":"photo","sizes":{"thumb":{"w":150,"h":150,"resize":"crop"},"small":{"w":340,"h":191,"resize":"fit"},"large":{"w":660,"h":371,"resize":"fit"},"medium":{"w":600,"h":337,"resize":"fit"}}}]},"extended_entities":{"media":[{"id":697549899282264065,"id_str":"697549899282264065","indices":[79,102],"media_url":"http:\\/\\/pbs.twimg.com\\/media\\/Ca4x8AfUMAE7nin.jpg","media_url_https":"https:\\/\\/pbs.twimg.com\\/media\\/Ca4x8AfUMAE7nin.jpg","url":"https:\\/\\/t.co\\/erE4PGH69s","display_url":"pic.twitter.com\\/erE4PGH69s","expanded_url":"http:\\/\\/twitter.com\\/kogcord\\/status\\/697549899416514561\\/photo\\/1","type":"photo","sizes":{"thumb":{"w":150,"h":150,"resize":"crop"},"small":{"w":340,"h":191,"resize":"fit"},"large":{"w":660,"h":371,"resize":"fit"},"medium":{"w":600,"h":337,"resize":"fit"}}}]},"favorited":false,"retweeted":false,"possibly_sensitive":false,"filter_level":"low","lang":"en","timestamp_ms":"1455143830528"}',
#  '{"created_at":"Wed Feb 10 22:37:16 +0000 2016","id":697549924225806336,"id_str":"697549924225806336","text":"RT @thehill: Jane Sanders on Bernie\'s age: \\"75 is the new 55\\" https:\\/\\/t.co\\/mUowKMHxIC https:\\/\\/t.co\\/8zae8iHxii","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":3663025166,"id_str":"3663025166","name":"Rena S.","screen_name":"Say_Non_Now","location":null,"url":null,"description":"#StopTPP #NoAlTPP #StopTiSA","protected":false,"verified":false,"followers_count":260,"friends_count":306,"listed_count":29,"favourites_count":1874,"statuses_count":8184,"created_at":"Wed Sep 23 20:44:51 +0000 2015","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/685501146421719041\\/Vd7WEXEx_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/685501146421719041\\/Vd7WEXEx_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/3663025166\\/1452272290","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 22:25:06 +0000 2016","id":697546864678334464,"id_str":"697546864678334464","text":"Jane Sanders on Bernie\'s age: \\"75 is the new 55\\" https:\\/\\/t.co\\/mUowKMHxIC https:\\/\\/t.co\\/8zae8iHxii","source":"\\u003ca href=\\"http:\\/\\/www.socialflow.com\\" rel=\\"nofollow\\"\\u003eSocialFlow\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1917731,"id_str":"1917731","name":"The Hill","screen_name":"thehill","location":"Washington, DC","url":"http:\\/\\/www.thehill.com","description":"The Hill is the premier source for policy and political news. Follow for tweets on what\'s happening in Washington, breaking news and retweets of our reporters.","protected":false,"verified":true,"followers_count":663376,"friends_count":382,"listed_count":15988,"favourites_count":26,"statuses_count":161879,"created_at":"Thu Mar 22 18:15:18 +0000 2007","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"9AE4E8","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/2509428\\/twitter_bg.gif","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/2509428\\/twitter_bg.gif","profile_background_tile":true,"profile_link_color":"FF0021","profile_sidebar_border_color":"ADADAA","profile_sidebar_fill_color":"EBEBEB","profile_text_color":"000000","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/433007452083060737\\/J_Mq7AKo_normal.jpeg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/433007452083060737\\/J_Mq7AKo_normal.jpeg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/1917731\\/1434034905","default_profile":false,"default_profile_image":false,"following":null,"follow ...
#  '{"created_at":"Wed Feb 10 22:37:38 +0000 2016","id":697550014709526528,"id_str":"697550014709526528","text":"RT @Hatsfree: Dozens! https:\\/\\/t.co\\/wK8TWXlKgr","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web Client\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":26883100,"id_str":"26883100","name":"Carlisleboy","screen_name":"Carlisleboy","location":"Nome Alaska","url":"http:\\/\\/dutchharbordirt.blogspot.com\\/","description":"Hotel and property manager in Nome Alaska , with a quirky view on the world and a great love of books. All RT\'s are interesting but not always shared views.","protected":false,"verified":false,"followers_count":1725,"friends_count":1756,"listed_count":88,"favourites_count":25,"statuses_count":93104,"created_at":"Thu Mar 26 23:15:12 +0000 2009","utc_offset":-32400,"time_zone":"Alaska","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme9\\/bg.gif","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme9\\/bg.gif","profile_background_tile":false,"profile_link_color":"89C9FA","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/465387725684617216\\/yxZZndwd_normal.jpeg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/465387725684617216\\/yxZZndwd_normal.jpeg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/26883100\\/1399792025","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 22:32:33 +0000 2016","id":697548739053924352,"id_str":"697548739053924352","text":"Dozens! https:\\/\\/t.co\\/wK8TWXlKgr","source":"\\u003ca href=\\"http:\\/\\/www.twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter for Windows\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":482501997,"id_str":"482501997","name":"Hattie Kauffman","screen_name":"Hatsfree","location":null,"url":"http:\\/\\/hattiekauffman.com","description":"Veteran journalist, speaker, and author of Falling Into Place.","protected":false,"verified":false,"followers_count":803,"friends_count":421,"listed_count":42,"favourites_count":724,"statuses_count":17789,"created_at":"Sat Feb 04 00:15:24 +0000 2012","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/490911364467011584\\/sKkkd1If_normal.jpeg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/490911364467011584\\/sKkkd1If_normal.jpeg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/482501997\\/1405877970","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"quoted_status_id":697541299231203331,"q ...
#  '{"created_at":"Wed Feb 10 22:38:46 +0000 2016","id":697550301805477888,"id_str":"697550301805477888","text":"RT @aprogresista: Soberanistas quieren votar por el Presidente del Imperio... #apagayvamonos #CEROdignidad #bochorno #TeamColorao  https:\\/\\/\\u2026","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\"\\u003eTwitter for Android\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1117969862,"id_str":"1117969862","name":"Danny","screen_name":"darroyo04","location":"New Puerto Rico, USA","url":null,"description":"Kid of America | PNP\\/Libertarian | #PierluisiPesquera2016 #LaJuventudDiceQueS\\u00ed | #ReadyForHillary | NewPuertoRico: 51st Star of the AmericanUnion #Admisi\\u00f3nYa","protected":false,"verified":false,"followers_count":1557,"friends_count":827,"listed_count":46,"favourites_count":46020,"statuses_count":162944,"created_at":"Thu Jan 24 23:43:39 +0000 2013","utc_offset":-14400,"time_zone":"Atlantic Time (Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"550575","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/472514807690571776\\/D7xm9CV3.png","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/472514807690571776\\/D7xm9CV3.png","profile_background_tile":true,"profile_link_color":"DD2E44","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"0D00C9","profile_use_background_image":false,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/691017117160706048\\/rz1I2KI9_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/691017117160706048\\/rz1I2KI9_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/1117969862\\/1454022246","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Wed Feb 10 22:38:18 +0000 2016","id":697550182532149249,"id_str":"697550182532149249","text":"Soberanistas quieren votar por el Presidente del Imperio... #apagayvamonos #CEROdignidad #bochorno #TeamColorao  https:\\/\\/t.co\\/I8QtPX3IF8","source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":280599871,"id_str":"280599871","name":"Alerta Progresista","screen_name":"aprogresista","location":"San Juan, Puerto Rico","url":null,"description":"\\u00danete a Alerta Progresista, el movimiento pol\\u00edtico en las redes m\\u00e1s grande en Puerto Rico: http:\\/\\/www.facebook.com\\/alertaprogresista","protected":false,"verified":false,"followers_count":12771,"friends_count":1235,"listed_count":63,"favourites_count":105,"statuses_count":45904,"created_at":"Mon Apr 11 17:13:08 +0000 2011","utc_offset":-18000,"time_zone":"Quito","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"FFFFFF","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/609072872787566592\\/WEOHlXcG.png","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/609072872787566592\\/WEOHlXcG.png","profile_background_tile":true,"profile_link_color":"17235C","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"56869E","profile_text_color":"072D4A","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/528164587892260866\\/Gh ...

# %% [markdown]
# ## Part 1: Parse JSON strings to JSON objects

# %% [markdown]
# Python has built-in support for JSON.

# %%
import json

json_example = '''
{
    "id": 1,
    "name": "A green door",
    "price": 12.50,
    "tags": ["home", "green"]
}
'''

json_obj = json.loads(json_example)
json_obj
# Out:
# {'id': 1, 'name': 'A green door', 'price': 12.5, 'tags': ['home', 'green']}

# %% [markdown]
# ### Broken tweets and irrelevant messages
#
# The data of this assignment may contain broken tweets (invalid JSON strings). So make sure that your code is robust for such cases.
#
# You can filter out such broken tweet by checking if:
# * the line is not in json format
#
# In addition, some lines in the input file might not be tweets, but messages that the Twitter server sent to the developer (such as limit notices). Your program should also ignore these messages.
#
# These messages would not contain the `created_at` field and can be filtered out accordingly.
# * Check if json object of the broken tweet has a `created_at` field
#
# **Hint:** [Catch the ValueError](http://stackoverflow.com/questions/11294535/verify-if-a-string-is-json-in-python)
#
# **Tasks:**
#
# 1. Parse raw JSON tweets stored in the RDD you created above to obtain **valid** JSON objects.
# 1. From all valid tweets, construct a pair RDD of `(user_id, text)`, where `user_id` is the `id_str` data field of the `user` dictionary (read [Tweets](#Tweets) section above), `text` is the `text` data field.

# %%
import json

def safe_parse(raw_json):
    """
    Input is a String
    Output is a JSON object if the tweet is valid and None if not valid
    """

    ###
    ### YOUR CODE HERE
    ###
    
    # Test if a raw_json is valid json. Returns None if not valid  
    try:
        json_object = json.loads(raw_json)
    except ValueError as e:
        #print('Invalid input string.')
        return None
    
    # Test if "created_at" key is in json_object. Returns None if not.
    if "created_at" in json_object:
        return json_object
    else:
        #print('"created_at" key not found.')
        return None

# %%
# Tests
'''safe_parse('{}')              # prints True
safe_parse('{asdf}')          # prints False
safe_parse('{"age":100}')     # prints True
safe_parse('{age:100 }')      # prints False
safe_parse('{"age":100 }')    # prints True'''

test_string = '{"created_at":"Tue Feb 23 17:42:36 +0000 2016","id":702186809468526592,"id_str":"702186809468526592","text":"RT @C0nservativeGal: Well , I\'m Conservative Southern Bapist and I\'m 4 #Trump-Southern Baptist leader: Donald Trump is not our friend https\\u2026","source":"\\u003ca href=\\"http:\\/\\/www.twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter for Windows\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":229594092,"id_str":"229594092","name":"paul wagner","screen_name":"bearbear9876","location":null,"url":null,"description":null,"protected":false,"verified":false,"followers_count":47,"friends_count":24,"listed_count":6,"favourites_count":1846,"statuses_count":2849,"created_at":"Wed Dec 22 20:25:15 +0000 2010","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/abs.twimg.com\\/sticky\\/default_profile_images\\/default_profile_0_normal.png","profile_image_url_https":"https:\\/\\/abs.twimg.com\\/sticky\\/default_profile_images\\/default_profile_0_normal.png","default_profile":true,"default_profile_image":true,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Tue Feb 23 17:14:11 +0000 2016","id":702179658717077504,"id_str":"702179658717077504","text":"Well , I\'m Conservative Southern Bapist and I\'m 4 #Trump-Southern Baptist leader: Donald Trump is not our friend https:\\/\\/t.co\\/nYUt4qn6S9","source":"\\u003ca href=\\"http:\\/\\/mobile.twitter.com\\" rel=\\"nofollow\\"\\u003eMobile Web\\u003c\\/a\\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":185906955,"id_str":"185906955","name":"Johanna","screen_name":"C0nservativeGal","location":"USA","url":"http:\\/\\/uspresidentialelectionnews.com","description":"I\'m a kick ass conservachick whose mission is to secure freedom, eliminate liberalism and look good doing it! No DMs #Christian #WhoDatNation #Trump2016","protected":false,"verified":false,"followers_count":34822,"friends_count":28947,"listed_count":306,"favourites_count":19910,"statuses_count":31801,"created_at":"Thu Sep 02 03:13:57 +0000 2010","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\\/\\/pbs.twimg.com\\/profile_background_images\\/687403539\\/729718c7391e53acaf7d6ac43f3c959e.jpeg","profile_background_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_background_images\\/687403539\\/729718c7391e53acaf7d6ac43f3c959e.jpeg","profile_background_tile":true,"profile_link_color":"E854E8","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/688571288563003392\\/HXtUWGWa_normal.png","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/688571288563003392\\/HXtUWGWa_normal.png","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":32,"favorite_count":43,"entities":{"hashtags":[{"text":"Trump","indices":[50,56]}],"urls":[{"url":"https:\\/\\/t.co\\/nYUt4qn6S9","expanded_url":"http:\\/\\/www.al.com\\/news\\/index.ssf\\/2015\\/09\\/southern_baptist_leader_donald.html","display_url":"al.com\\/news\\/index.ssf\\u2026","indices":[113,136]}],"user_mentions":[],"symbols":[]},"favorited":false,"retweeted":false,"possibly_sensitive":false,"filter_level":"low","lang":"en"},"is_quote_status":false,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[{"text":"Trump","indices":[71,77]}],"urls":[{"url":"https:\\/\\/t.co\\/nYUt4qn6S9","expanded_url":"http:\\/\\/www.al.com\\/news\\/index.ssf\\/2015\\/09\\/southern_baptist_leader_donald.html","display_url":"al.com\\/news\\/index.ssf\\u2026","indices":[139,140]}],"user_mentions":[{"screen_name":"C0nservativeGal","name":"Johanna","id":185906955,"id_str":"185906955","indices":[3,19]}],"symbols":[]},"favorited":false,"retweeted":false,"possibly_sensitive":false,"filter_level":"low","lang":"en","timestamp_ms":"1456249356034"}'
test_json_object = safe_parse(test_string)
#print(test_json_object)
if test_json_object is None:
    print(test_json_object)
else:
    for k, v in test_json_object.items():
        print(k, ' => ', v)
# Out:
# created_at  =>  Tue Feb 23 17:42:36 +0000 2016
# id  =>  702186809468526592
# id_str  =>  702186809468526592
# text  =>  RT @C0nservativeGal: Well , I'm Conservative Southern Bapist and I'm 4 #Trump-Southern Baptist leader: Donald Trump is not our friend https…
# source  =>  <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows</a>
# truncated  =>  False
# in_reply_to_status_id  =>  None
# in_reply_to_status_id_str  =>  None
# in_reply_to_user_id  =>  None
# in_reply_to_user_id_str  =>  None
# in_reply_to_screen_name  =>  None
# user  =>  {'id': 229594092, 'id_str': '229594092', 'name': 'paul wagner', 'screen_name': 'bearbear9876', 'location': None, 'url': None, 'description': None, 'protected': False, 'verified': False, 'followers_count': 47, 'friends_count': 24, 'listed_count': 6, 'favourites_count': 1846, 'statuses_count': 2849, 'created_at': 'Wed Dec 22 20:25:15 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png', 'default_profile': True, 'default_profile_image': True, 'following': None, 'follow_request_sent': None, 'notifications': None}
# geo  =>  None
# coordinates  =>  None
# place  =>  None
# contributors  =>  None
# retweeted_status  =>  {'created_at': 'Tue Feb 23 17:14:11 +0000 2016', 'id': 702179658717077504, 'id_str': '702179658717077504', 'text': "Well , I'm Conservative Southern Bapist and I'm 4 #Trump-Southern Baptist leader: Donald Trump is not our friend https://t.co/nYUt4qn6S9", 'source': '<a href="http://mobile.twitter.com" rel="nofollow">Mobile Web</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 185906955, 'id_str': '185906955', 'name': 'Johanna', 'screen_name': 'C0nservativeGal', 'location': 'USA', 'url': 'http://uspresidentialelectionnews.com', 'description': "I'm a kick ass conservachick whose mission is to secure freedom, eliminate liberalism and look good doing it! No DMs #Christian #WhoDatNation #Trump2016", 'protected': False, 'verified': False, 'followers_count': 34822, 'friends_count': 28947, 'listed_count': 306, 'favourites_count': 19910, 'statuses_count': 31801, 'created_at': 'Thu Sep 02 03:13:57 +0000 2010', 'utc_offset': -18000, 'time_zone': 'Eastern Time (US & Canada)', 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/687403539/729718c7391e53acaf7d6ac43f3c959e.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/687403539/729718c7391e53acaf7d6ac43f3c959e.jpeg', 'profile_background_tile': True, 'profile_link_color': 'E854E8', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/688571288563003392/HXtUWGWa_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/688571288563003392/HXtUWGWa_normal.png', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 32, 'favorite_count': 43, 'entities': {'hashtags': [{'text': 'Trump', 'indices': [50, 56]}], 'urls': [{'url': 'https://t.co/nYUt4qn6S9', 'expanded_url': 'http://www.al.com/news/index.ssf/2015/09/southern_baptist_leader_donald.html', 'display_url': 'al.com/news/index.ssf…', 'indices': [113, 136]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en'}
# is_quote_status  =>  False
# retweet_count  =>  0
# favorite_count  =>  0
# entities  =>  {'hashtags': [{'text': 'Trump', 'indices': [71, 77]}], 'urls': [{'url': 'https://t.co/nYUt4qn6S9', 'expanded_url': 'http://www.al.com/news/index.ssf/2015/09/southern_baptist_leader_donald.html', 'display_url': 'al.com/news/index.ssf…', 'indices': [139, 140]}], 'user_mentions': [{'screen_name': 'C0nservativeGal', 'name': 'Johanna', 'id': 185906955, 'id_str': '185906955', 'indices': [3, 19]}], 'symbols': []}
# favorited  =>  False
# retweeted  =>  False
# possibly_sensitive  =>  False
# filter_level  =>  low
# lang  =>  en
# timestamp_ms  =>  1456249356034

# %%
"""
# Remember to construct an RDD of (user_id, text) here.
"""

###
### YOUR CODE HERE
###
rdd_valid_tweets = rdd.map(safe_parse).filter(lambda x: x!=None).map(lambda x: (x['user']['id_str'], x['text']))

# %%
# Tests
'''n = rdd_valid_tweets.count()
print('Number of elements: ', n)

m = 5
rdd_sample = rdd_valid_tweets.sample(False, m/n).collect()
print(f'A sample of {len(rdd_sample)} elements:\n')
for item in rdd_sample:
    print(item)'''
# Out:
# "n = rdd_valid_tweets.count()\nprint('Number of elements: ', n)\n\nm = 5\nrdd_sample = rdd_valid_tweets.sample(False, m/n).collect()\nprint(f'A sample of {len(rdd_sample)} elements:\n')\nfor item in rdd_sample:\n    print(item)"

# %% [markdown]
# ### Number of unique users
#
# **Tasks:**
#
# 1. Count the number of different users in all valid tweets and store the result in `num_unique_users`.
#
# **Hint:** use the [`distinct()`](https://spark.apache.org/docs/2.3.0/api/python/pyspark.html#pyspark.RDD.distinct) method.
#
# ***
#
# **It should print**
# ```
# The number of unique users is: 1748
# ```

# %%
save_time("count unique users")

###
### YOUR CODE HERE
###
num_unique_users = rdd_valid_tweets.map(lambda x: x[0]).distinct().count()

my_output.append("num-unique-users", num_unique_users)
print('The number of unique users is:', num_unique_users)
save_time("count unique users")
# Out:
# The number of unique users is: 110802

# %% [markdown]
# ## Part 2: Number of posts from each user partition

# %% [markdown]
# ### Load the pickle file
#
# Load the Pickle file `users-partition.pickle`, you will get a dictionary which represents a partition over 452,743 Twitter users, `{user_id: partition_id}`. The users are partitioned into 7 groups. For example, if the dictionary is loaded into a variable named `partition`, the partition ID of the user `59458445` is `partition["59458445"]`. These users are partitioned into 7 groups. The partition ID is an integer between 0-6.
#
# Note that the user partition we provide doesn't cover all users appear in the input data.

# %%
import subprocess
import pickle

if ON_EMR:
    command = ["/usr/local/hadoop/hadoop-2.7.4/bin/hadoop", "fs", "-cat", "/user/spark/twitter/users-partition.pickle"]
else:
    command = ["cat", "./resource/asnlib/publicdata/users-partition.pickle"]
    
proc = subprocess.Popen(command, stdout=subprocess.PIPE)
pickle_content = proc.communicate()[0]
partition = pickle.loads(pickle_content)
len(partition)
# Out:
# 452743

# %% [markdown]
# ### Tweets per user partition
#
# **Tasks:**
#
# 1. Count the number of posts from group 0, 1, ..., 6, plus the number of posts from users who are not in any partition. Assign users who are not in any partition to the group 7.
# 1. Put the results of this step into a pair RDD `(group_id, count)` that is sorted by key.
# 1. Collect the RDD to get `counts_per_part` list.
#
# ***
#
# **It should print**
#
# ```
# Group 0 posted 87 tweets
# Group 1 posted 242 tweets
# Group 2 posted 41 tweets
# Group 3 posted 349 tweets
# Group 4 posted 101 tweets
# Group 5 posted 358 tweets
# Group 6 posted 434 tweets
# Group 7 posted 521 tweets
# ```

# %%
def print_post_count(counts):
    for group_id, count in counts:
        print('Group %d posted %d tweets' % (group_id, count))

# %%
save_time("count tweets per user partition")

###
### YOUR CODE HERE
###

# Convert partition dict to (key, val) RDD 
rdd_partition = sc.parallelize(partition.items())

# Left Outer Join rdd_valid_tweets with rdd_partition based on user_id. If user_id not found in rdd_partition assign 7 as partition
rdd_lojoin_by_user_id = rdd_valid_tweets.leftOuterJoin(rdd_partition)
rdd_by_partition = rdd_lojoin_by_user_id.map(lambda x: (x[1][1] if x[1][1] in range(7) else 7, [x[0], x[1][0]])).cache()
rdd_counts_per_part = sc.parallelize(rdd_by_partition.countByKey().items()).sortByKey()
counts_per_part = rdd_counts_per_part.collect()

# Following code adds your solution to `my_output`
assert(type(counts_per_part) is list and
       len(counts_per_part) == 8 and
       len(counts_per_part[0]) == 2)
print_post_count(counts_per_part)
my_output.append("counts_per_part", counts_per_part)
save_time("count tweets per user partition")
# Out:
# Group 0 posted 9631 tweets
# Group 1 posted 27661 tweets
# Group 2 posted 5037 tweets
# Group 3 posted 29918 tweets
# Group 4 posted 14182 tweets
# Group 5 posted 25174 tweets
# Group 6 posted 28891 tweets
# Group 7 posted 81077 tweets

# %% [markdown]
# ## Part 3:  Tokens that are relatively popular in each user partition

# %% [markdown]
# In this step, we are going to find tokens that are relatively popular in each user partition.
#
# We define the number of mentions of a token $t$ in a specific user partition $k$ as the number of users from the user partition $k$ that ever mentioned the token $t$ in their tweets. Note that even if some users might mention a token $t$ multiple times or in multiple tweets, a user will contribute at most 1 to the counter of the token $t$.
#
# Please make sure that the number of mentions of a token is equal to the number of users who mentioned this token but NOT the number of tweets that mentioned this token.
#
# Let $N_t^k$ be the number of mentions of the token $t$ in the user partition $k$. Let $N_t^{all} = \sum_{i=0}^7 N_t^{i}$ be the number of total mentions of the token $t$.
#
# We define the relative popularity of a token $t$ in a user partition $k$ as the log ratio between $N_t^k$ and $N_t^{all}$, i.e.
#
# \begin{equation}
# p_t^k = \log \frac{N_t^k}{N_t^{all}}.
# \end{equation}
#
#
# You can compute the relative popularity by calling the function `get_rel_popularity`.

# %% [markdown]
# We load a tweet tokenizer for you in the following cells. This Tokenizer object is called `tok`. Don't forget to execute the two cells below.
#
# You can expand the following cell if needed to see the minutae of the Tokenizer.

# %%
#!/usr/bin/env python

"""
This code implements a basic, Twitter-aware tokenizer.

A tokenizer is a function that splits a string of text into words. In
Python terms, we map string and unicode objects into lists of unicode
objects.

There is not a single right way to do tokenizing. The best method
depends on the application.  This tokenizer is designed to be flexible
and this easy to adapt to new domains and tasks.  The basic logic is
this:

1. The tuple regex_strings defines a list of regular expression
   strings.

2. The regex_strings strings are put, in order, into a compiled
   regular expression object called word_re.

3. The tokenization is done by word_re.findall(s), where s is the
   user-supplied string, inside the tokenize() method of the class
   Tokenizer.

4. When instantiating Tokenizer objects, there is a single option:
   preserve_case.  By default, it is set to True. If it is set to
   False, then the tokenizer will downcase everything except for
   emoticons.

The __main__ method illustrates by tokenizing a few examples.

I've also included a Tokenizer method tokenize_random_tweet(). If the
twitter library is installed (http://code.google.com/p/python-twitter/)
and Twitter is cooperating, then it should tokenize a random
English-language tweet.


Julaiti Alafate:
  I modified the regex strings to extract URLs in tweets.
"""

__author__ = "Christopher Potts"
__copyright__ = "Copyright 2011, Christopher Potts"
__credits__ = []
__license__ = "Creative Commons Attribution-NonCommercial-ShareAlike 3.0 Unported License: http://creativecommons.org/licenses/by-nc-sa/3.0/"
__version__ = "1.0"
__maintainer__ = "Christopher Potts"
__email__ = "See the author's website"

######################################################################

import re
from html import entities 

######################################################################
# The following strings are components in the regular expression
# that is used for tokenizing. It's important that phone_number
# appears first in the final regex (since it can contain whitespace).
# It also could matter that tags comes after emoticons, due to the
# possibility of having text like
#
#     <:| and some text >:)
#
# Most imporatantly, the final element should always be last, since it
# does a last ditch whitespace-based tokenization of whatever is left.

# This particular element is used in a couple ways, so we define it
# with a name:
emoticon_string = r"""
    (?:
      [<>]?
      [:;=8]                     # eyes
      [\-o\*\']?                 # optional nose
      [\)\]\(\[dDpP/\:\}\{@\|\\] # mouth      
      |
      [\)\]\(\[dDpP/\:\}\{@\|\\] # mouth
      [\-o\*\']?                 # optional nose
      [:;=8]                     # eyes
      [<>]?
    )"""

# The components of the tokenizer:
regex_strings = (
    # Phone numbers:
    r"""
    (?:
      (?:            # (international)
        \+?[01]
        [\-\s.]*
      )?            
      (?:            # (area code)
        [\(]?
        \d{3}
        [\-\s.\)]*
      )?    
      \d{3}          # exchange
      [\-\s.]*   
      \d{4}          # base
    )"""
    ,
    # URLs:
    r"""http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"""
    ,
    # Emoticons:
    emoticon_string
    ,    
    # HTML tags:
     r"""<[^>]+>"""
    ,
    # Twitter username:
    r"""(?:@[\w_]+)"""
    ,
    # Twitter hashtags:
    r"""(?:\#+[\w_]+[\w\'_\-]*[\w_]+)"""
    ,
    # Remaining word types:
    r"""
    (?:[a-z][a-z'\-_]+[a-z])       # Words with apostrophes or dashes.
    |
    (?:[+\-]?\d+[,/.:-]\d+[+\-]?)  # Numbers, including fractions, decimals.
    |
    (?:[\w_]+)                     # Words without apostrophes or dashes.
    |
    (?:\.(?:\s*\.){1,})            # Ellipsis dots. 
    |
    (?:\S)                         # Everything else that isn't whitespace.
    """
    )

######################################################################
# This is the core tokenizing regex:
    
word_re = re.compile(r"""(%s)""" % "|".join(regex_strings), re.VERBOSE | re.I | re.UNICODE)

# The emoticon string gets its own regex so that we can preserve case for them as needed:
emoticon_re = re.compile(regex_strings[1], re.VERBOSE | re.I | re.UNICODE)

# These are for regularizing HTML entities to Unicode:
html_entity_digit_re = re.compile(r"&#\d+;")
html_entity_alpha_re = re.compile(r"&\w+;")
amp = "&amp;"

######################################################################

class Tokenizer:
    def __init__(self, preserve_case=False):
        self.preserve_case = preserve_case

    def tokenize(self, s):
        """
        Argument: s -- any string or unicode object
        Value: a tokenize list of strings; conatenating this list returns the original string if preserve_case=False
        """        
        # Try to ensure unicode:
        try:
            s = str(s)
        except UnicodeDecodeError:
            s = s.encode('string_escape')
            s = str(s)
        # Fix HTML character entitites:
        s = self.__html2unicode(s)
        # Tokenize:
        words = word_re.findall(s)
        # Possible alter the case, but avoid changing emoticons like :D into :d:
        if not self.preserve_case:            
            words = list(map((lambda x : x if emoticon_re.search(x) else x.lower()), words))
        return words

    def tokenize_random_tweet(self):
        """
        If the twitter library is installed and a twitter connection
        can be established, then tokenize a random tweet.
        """
        try:
            import twitter
        except ImportError:
            print("Apologies. The random tweet functionality requires the Python twitter library: http://code.google.com/p/python-twitter/")
        from random import shuffle
        api = twitter.Api()
        tweets = api.GetPublicTimeline()
        if tweets:
            for tweet in tweets:
                if tweet.user.lang == 'en':            
                    return self.tokenize(tweet.text)
        else:
            raise Exception("Apologies. I couldn't get Twitter to give me a public English-language tweet. Perhaps try again")

    def __html2unicode(self, s):
        """
        Internal metod that seeks to replace all the HTML entities in
        s with their corresponding unicode characters.
        """
        # First the digits:
        ents = set(html_entity_digit_re.findall(s))
        if len(ents) > 0:
            for ent in ents:
                entnum = ent[2:-1]
                try:
                    entnum = int(entnum)
                    s = s.replace(ent, unichr(entnum))	
                except:
                    pass
        # Now the alpha versions:
        ents = set(html_entity_alpha_re.findall(s))
        ents = filter((lambda x : x != amp), ents)
        for ent in ents:
            entname = ent[1:-1]
            try:            
                s = s.replace(ent, unichr(entities.name2codepoint[entname]))
            except:
                pass                    
            s = s.replace(amp, " and ")
        return s

# %%
from math import log

tok = Tokenizer(preserve_case=False)

def get_rel_popularity(c_k, c_all):
    '''
    Compute the relative popularity of a token.
    
    Args:
        c_k: the number of mentions in the user partition k.
        c_all: the number of all mentions.
        
    Return:
        The relative popularity of the token. It should be a negative number due to the log function. 
    '''
    
    return log(1.0 * c_k / c_all) / log(2)

def print_tokens(tokens, gid=None):
    group_name = "overall"
    if gid is not None:
        group_name = "group %d" % gid
        
    print('=' * 5 + ' ' + group_name + ' ' + '=' * 5)
    for t, n in tokens:
        print("%s\t%.4f" % (t, n))
    print

# %% [markdown]
# ### Tokenize tweets
#
# **Tasks:**
#
# 1. Tokenize the tweets using the `tokenize` function that is a method of the `Tokenizer` class that we have instantiated as `tok`.
# 1. Count the number of mentions for each tokens regardless of specific user group and store them in a RDD, which will be used later.
# 1. Get `num_of_tokens`, which is how many different tokens we have.
#
# ---
#
# **It should print**
# ```
# Number of tokens: 7677
# ```

# %%
save_time("count all unique tokens")

###
### YOUR CODE HERE
###

# Tokenize tweets
rdd_tok = rdd_by_partition.flatMap(lambda x: tok.tokenize(x[1][1]))

# Count tokens
rdd_tok_val = rdd_tok.map(lambda tok: (tok, 1))
rdd_counts_tok = rdd_tok_val.reduceByKey(lambda a, b: a + b)

# Get num_of_tokens
num_of_tokens = rdd_counts_tok.distinct().count()

my_output.append("num-tokens", num_of_tokens)
print("Number of tokens:", num_of_tokens)
save_time("count all unique tokens")
# Out:
# Number of tokens: 176481

# %% [markdown]
# ### Token popularity
#
# Tokens that are mentioned by too few users are usually not very interesting. So we want to only keep tokens that are mentioned by at least 100 users. Filter out tokens that don't meet this requirement.
#
# **Tasks:**
#
# 1. Compute the two varaibles below:
#     1. `num_freq_tokens`: an int of how many different tokens we have after the filtering.
#     1. `top20`: a list that contains the top 20 most frequent tokens after the filtering.
#
# ---
#
# **It should print**
# ```
# Number of tokens: 46
# ===== overall =====
# :	1046.0000
# rt	920.0000
# .	767.0000
# the	587.0000
# trump	560.0000
# …	520.0000
# to	501.0000
# ,	497.0000
# in	385.0000
# a	383.0000
# is	382.0000
# of	300.0000
# !	285.0000
# for	275.0000
# and	263.0000
# on	218.0000
# i	216.0000
# he	191.0000
# that	190.0000
# "	181.0000
# ```

# %%
save_time("count overall most popular tokens")

###
### YOUR CODE HERE
###

# Create RDD mapping each token to each user_id. Eliminate duplicates i.e. keep unique pairs (token, user_id).
rdd_tok_by_users = rdd_by_partition.flatMap(lambda x: [(t, x[1][0]) for t in tok.tokenize(x[1][1])]).distinct()

# Create RDD counting the number of unique user_id which mention each token.
rdd_tok_by_user_count = rdd_tok_by_users.groupByKey().map(lambda x: (x[0], len([i for i in x[1]])))

# Filter tokens mentioned at least by 100 users. Sort by highest occurence.
rdd_tok_by_user_count_filt = rdd_tok_by_user_count.filter(lambda x: x[1] >= 100).sortBy(lambda x: x[1], ascending=False)

# Get number of tokens mentioned at least by 100 users
num_freq_tokens = rdd_tok_by_user_count_filt.count()

# Get a list of top 20 most frequent tokens
top20 = rdd_tok_by_user_count_filt.take(20)

my_output.append("num-freq-tokens", num_freq_tokens)
my_output.append("top-20-tokens", top20)
print("Number of tokens:", num_freq_tokens)
print_tokens(top20)
save_time("count overall most popular tokens")
# Out:
# Number of tokens: 2882
# ===== overall =====
# :	72738.0000
# rt	61725.0000
# .	52166.0000
# the	43342.0000
# ,	33627.0000
# to	33090.0000
# …	31795.0000
# trump	30498.0000
# for	28707.0000
# in	28207.0000
# a	28076.0000
# is	26959.0000
# of	24136.0000
# and	19967.0000
# sanders	18676.0000
# bernie	17908.0000
# i	16035.0000
# ?	14852.0000
# on	14164.0000
# !	14134.0000

# %% [markdown]
# ### Relative Popularity
#
# For all tokens that are mentioned by at least 100 users, compute their relative popularity in each user group. Then print the top 10 tokens with highest relative popularity in each user group. In case two tokens have same relative popularity, break the tie by printing the alphabetically smaller one first.
#
# **Tasks:**
#
# 1. Calculate `popular_10_in_each_group` list, in which the `i`-th element is a list of 10 (token, relative popularity) pair that are top 10 tokens with highest relative popularity in the `i`-th user group.
#
# **Hint:** Let the relative popularity of a token $t$ be $p$. The order of the items will be satisfied by sorting them using (-p, t) as the key.
#
# ---
#
# **It should print**
# ```
# ===== group 0 =====
# with	-3.6088
# cruz	-3.6554
# his	-3.6582
# amp	-3.8651
# on	-3.9608
# to	-4.0145
# &	-4.0875
# https	-4.1699
# i	-4.1699
# what	-4.1699
# ===== group 1 =====
# sanders	-2.2854
# gop	-2.4060
# hillary	-2.4330
# ’	-2.4463
# bernie	-2.4835
# "	-2.6925
# are	-2.7249
# this	-2.7633
# for	-2.8179
# about	-2.8346
# ===== group 2 =====
# with	-4.3458
# donald	-4.5146
# ...	-4.7004
# gop	-4.7279
# i	-4.9475
# on	-4.9608
# he	-4.9925
# …	-5.1155
# https	-5.1699
# what	-5.1699
# ===== group 3 =====
# bernie	-1.5945
# sanders	-1.6609
# hillary	-2.2188
# and	-2.5154
# "	-2.5930
# in	-2.6114
# will	-2.6160
# https	-2.6674
# ...	-2.7004
# you	-2.7004
# ===== group 4 =====
# what	-3.4330
# have	-3.4725
# bernie	-3.5380
# this	-3.5518
# it	-3.6881
# ?	-3.6912
# for	-3.7110
# about	-3.7415
# hillary	-3.7549
# that	-3.7625
# ===== group 5 =====
# what	-1.8007
# not	-1.8745
# https	-2.0000
# his	-2.0144
# cruz	-2.0704
# it	-2.1031
# on	-2.1243
# &	-2.1399
# amp	-2.1489
# ;	-2.1592
# ===== group 6 =====
# will	-1.3847
# have	-1.4725
# !	-1.5850
# cruz	-1.6919
# trump	-1.7199
# https	-1.7549
# -	-1.7673
# ;	-1.7807
# be	-1.7952
# amp	-1.8144
# ===== group 7 =====
# donald	-1.0740
# trump	-1.6535
# bernie	-1.7790
# sanders	-1.7829
# ’	-1.8613
# of	-1.9069
# ?	-1.9186
# with	-1.9307
# the	-1.9588
# be	-1.9758
# ```

# %%
save_time("print popular tokens in each group")

###
### YOUR CODE HERE
###

# Create RDD mapping each (partition k, token t) to each user_id.
# Eliminate duplicates (a user may use several times the same token, has to be counted ONE use at most)
rdd_tok_by_users_and_group = rdd_by_partition.flatMap(lambda x: [(x[0], t, x[1][0]) for t in tok.tokenize(x[1][1])]).distinct()
rdd_tok_by_users_and_group = rdd_tok_by_users_and_group.map(lambda x: ((x[1], x[0]), x[2]))

# Create RDD counting the number of unique user_id, within each group, who mention each token.
rdd_tok_by_user_and_group_count = rdd_tok_by_users_and_group.groupByKey().map(lambda x: (x[0], len([i for i in x[1]])))
rdd_tok_by_user_and_group_count = rdd_tok_by_user_and_group_count.map(lambda x: (x[0][0], (x[0][1], x[1])))

# Join rdd_tok_by_user_and_group_count and rdd_tok_by_user_count_filt based on token t
rdd_join_by_tok = rdd_tok_by_user_and_group_count.join(rdd_tok_by_user_count_filt)
rdd_join_by_tok = rdd_join_by_tok.map(lambda x: (x[0], (x[1][0][0], x[1][0][1], x[1][1])))

# Compute relative popularity (p) and sort by (-p, t)
rdd_rel_pop = rdd_join_by_tok.map(lambda x: ((x[1][0], (x[0], get_rel_popularity(x[1][1],x[1][2])))))#.sortBy(lambda x: (-x[1][1], x[1][0]))
rdd_rel_pop = rdd_rel_pop.cache()

# Filter top 10 relative popularity in each group
popular_10_in_each_group = []
for item in rdd_rel_pop.groupByKey().collect():
    rdd_group = sc.parallelize(item[1])
    rdd_group = rdd_group.sortBy(lambda x: (-x[1], x[0]))
    popular_10_in_each_group.append(rdd_group.take(10))

my_output.append("popular_10_in_each_group", popular_10_in_each_group)
for k in range(8):
    print_tokens(popular_10_in_each_group[k], k)
save_time("print popular tokens in each group")
# Out:
# ===== group 0 =====
# https://t.co/zvEyoG	-1.6549
# https://t.co/VsRxX6puVq	-1.6646
# #newhampshire	-2.4549
# explanation	-2.5305
# #chrischristie	-2.5580
# o'malley	-2.5850
# perry	-2.5976
# pataki	-2.6067
# deja	-2.6280
# fallen	-2.6807
# ===== group 1 =====
# https://t.co/GOcxw2Uby1	-0.0098
# https://t.co/wEw3YnxWqs	-0.0098
# @viralbuzznewss	-0.0140
# https://t.co/cIyH6gRHtN	-0.0177
# #039s	-0.0186
# functioning	-0.0195
# vacant	-0.0196
# explaining	-0.2942
# #hillyes	-0.3076
# @hillaryfornv	-0.4463
# ===== group 2 =====
# fallout	-0.5228
# panic	-1.0713
# #election2016	-1.7790
# allies	-2.0934
# #politics	-2.4503
# coverage	-2.4655
# #decision2016	-2.7408
# –	-2.7891
# follow	-2.8642
# message	-2.9760
# ===== group 3 =====
# cezar	-0.0780
# #scforbernie	-0.0943
# mcknight	-0.0995
# #wearebernie	-0.1129
# @cezarmcknight	-0.1651
# @zaidjilani	-0.1684
# https://t.co/Q3UxjGcyQO	-0.1946
# @libertea2012	-0.2148
# @peaceaction	-0.2331
# @ninaturner	-0.2675
# ===== group 4 =====
# 163.5	-2.2515
# https://t.co/b0ejaaL4Ws	-2.3289
# sauce	-2.4199
# funded	-2.4935
# impudent	-2.4975
# warlord	-2.5050
# @wnyc	-2.5110
# @dprk_news	-2.5289
# self-beclowning	-2.5346
# https://t.co/dRGVvdaOcK	-2.5384
# ===== group 5 =====
# #cruztovictory	-0.1684
# #cruz2016	-0.1745
# @realbphil	-0.1769
# #choosecruz	-0.2035
# #trusted	-0.2379
# @patricksvitek	-0.2657
# rsvp	-0.2679
# arkansas	-0.2792
# https://t.co/m2rprqZyYs	-0.3187
# @rickwtyler	-0.3397
# ===== group 6 =====
# #votetrump2016	-0.0385
# @trumpnv	-0.0633
# https://t.co/YP7aMZueN8	-0.0654
# 🚂	-0.0664
# https://t.co/Z3qPVEmB0q	-0.0684
# @scteamtrump	-0.0701
# @johnatsrs1949	-0.0725
# #votetrumpsc	-0.0732
# 2-10-	-0.0813
# ☆	-0.0825
# ===== group 7 =====
# foi	0.0000
# sai	-0.0137
# @causewereguys	-0.0141
# https://t.co/5qvKRJWzX1	-0.0141
# pré	-0.0240
# https://t.co/O8ZGkipMGw	-0.0277
# @worldstarvlne	-0.0278
# #dienachrichten	-0.0281
# https://t.co/RmbdBa5t2b	-0.0281
# @methone	-0.0295

# %% [markdown]
# ## Important: Write your solutions to disk
#
# Following cell write your solutions to disk which would be read in by the grader for grading.

# %%
my_output.write_to_disk()

# %% [markdown]
# ## Runtime statistics of your implementation
#
# When you run locally, the runtime of your implementation printed here will **NOT** be an accurate reflection of how your implementation will run on clusters. The time it takes to run locally might be faster or slower than running on clusters depending on the resources of your device (if you develop on your own device) or the workload of the workbench (if you develop on Vocareum).
#
# If you want a relatively accurate estimate, please submit and see the runtime printed in the grading report. Note that the time estimated here in the grading report only considers the time it takes to run your application. There will be an inevitable overhead in grading to submit the Spark application and collect the logs, which will be included in the total runtime that will be used for grading.

# %%
save_time('total time')

for key in timer:
    print(key, timer[key])
# Out:
# total time 0:01:03
# set up sc 0:00:02
# read data 0:00:06
# count unique users 0:00:06
# count tweets per user partition 0:00:08
# count all unique tokens 0:00:04
# count overall most popular tokens 0:00:14
# print popular tokens in each group 0:00:20
